# %% [markdown]
# # Data Visualizer Project!
# ## Ursula Pollack, Nimisha Seshadri, & Nellie Cox
# ### What are some of the visually observable relationships between a micro business' Instagram posts?

# %% [markdown]
# All that is required to intiate the tool is import the script and call the main() function.

# %%
import crochet
crochet.main()
# Out:
#     Welcome to the plotter!
#     Choose a number from this menu:
#
# 0.	quit
# 1.	scatterplot
# 2.	timeline
# 3.	histogram
# 4.	boxplot
# 5.	barplot
# >  likes
# Please enter valid input
# 0.	quit
# 1.	scatterplot
# 2.	timeline
# 3.	histogram
# 4.	boxplot
# 5.	barplot
# >  1
# Choose some column names (case sensitive). Enter 1-2 inputs, separate with spaces. Inputs correspond to (x,y) respectively.
# >  likes comments
# 0.	quit
# 1.	scatterplot
# 2.	timeline
# 3.	histogram
# 4.	boxplot
# 5.	barplot
# >  1
# Choose some column names (case sensitive). Enter 1-2 inputs, separate with spaces. Inputs correspond to (x,y) respectively.
# >  impressions profile_visits
# 0.	quit
# 1.	scatterplot
# 2.	timeline
# 3.	histogram
# 4.	boxplot
# 5.	barplot
# >  2
# Choose some column names (case sensitive). Enter 1-2 inputs, separate with spaces. Inputs correspond to (x,y) respectively.
# >  like
# Please give valid column names:
# Date
# number_of_items_featured
# who's_featured
# product_type
# number_of_pictures_in_post
# likes
# comments
# saves
# shares
# impressions
# number_of_days_since_previous_post
# season
# profile_visits
# percent_weren't_following
# follows
# purpose
# general_product_types
# >  likes
# 0.	quit
# 1.	scatterplot
# 2.	timeline
# 3.	histogram
# 4.	boxplot
# 5.	barplot
# >  2
# Choose some column names (case sensitive). Enter 1-2 inputs, separate with spaces. Inputs correspond to (x,y) respectively.
# >  comments
# 0.	quit
# 1.	scatterplot
# 2.	timeline
# 3.	histogram
# 4.	boxplot
# 5.	barplot
# >  2
# Choose some column names (case sensitive). Enter 1-2 inputs, separate with spaces. Inputs correspond to (x,y) respectively.
# >  likes comments
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 import crochet
# ----> 2 crochet.main()
#
# File ~/Desktop/Final Version/crochet.py:282, in main()
#     279     print("Please enter valid input") # if not, except the mistake and reprompt
#     280     continue
# --> 282 runner(dataviz, func)
#
# File ~/Desktop/Final Version/crochet.py:225, in runner(viz, func)
#     223 try:
#     224     colnames = input(input_sym).split() # first try to read each word separated with a space as a column name
# --> 225     func(*colnames) # then put the column names into the method for validating
#     226     return
#     227 except KeyError: # if not, except KeyError
#
# File ~/Desktop/Final Version/crochet.py:98, in CrochetDataVisualizer.validate_column_dec.<locals>.ret_func(self, *pos, **kw)
#      95 @wraps(func)
#      96 def ret_func(self, *pos, **kw): # creates a function that can be applied to each plotting method
#      97     self.validate_columns(*pos) # specifies that validate_columns should only accept col names as positional args
# ---> 98     return func(self, *pos, **kw)
#
# TypeError: timeline() takes 2 positional arguments but 3 were given

# %% [markdown]
# We can call the main function to launch the visualizer again!

# %%
crochet.main()
# Out:
#     Welcome to the plotter!
#     Choose a number from this menu:
#
# 0.	quit
# 1.	scatterplot
# 2.	timeline
# 3.	histogram
# 4.	boxplot
# 5.	barplot
# >  3
# Choose some column names (case sensitive). Enter 1-2 inputs, separate with spaces. Inputs correspond to (x,y) respectively.
# >  likes comments saves
# 0.	quit
# 1.	scatterplot
# 2.	timeline
# 3.	histogram
# 4.	boxplot
# 5.	barplot
# >  3
# Choose some column names (case sensitive). Enter 1-2 inputs, separate with spaces. Inputs correspond to (x,y) respectively.
# >  profile_visits percent_weren't_following
# 0.	quit
# 1.	scatterplot
# 2.	timeline
# 3.	histogram
# 4.	boxplot
# 5.	barplot
# >  4
# Choose some column names (case sensitive). Enter 1-2 inputs, separate with spaces. Inputs correspond to (x,y) respectively.
# >  likes seasons
# Please give valid column names:
# Date
# number_of_items_featured
# who's_featured
# product_type
# number_of_pictures_in_post
# likes
# comments
# saves
# shares
# impressions
# number_of_days_since_previous_post
# season
# profile_visits
# percent_weren't_following
# follows
# purpose
# general_product_types
# >  likes season
# 0.	quit
# 1.	scatterplot
# 2.	timeline
# 3.	histogram
# 4.	boxplot
# 5.	barplot
# >  5
# Choose some column names (case sensitive). Enter 1-2 inputs, separate with spaces. Inputs correspond to (x,y) respectively.
# >  who's_featured likes
# 0.	quit
# 1.	scatterplot
# 2.	timeline
# 3.	histogram
# 4.	boxplot
# 5.	barplot
# >  5
# Choose some column names (case sensitive). Enter 1-2 inputs, separate with spaces. Inputs correspond to (x,y) respectively.
# >  who's_featured saves
# 0.	quit
# 1.	scatterplot
# 2.	timeline
# 3.	histogram
# 4.	boxplot
# 5.	barplot
# >  5
# Choose some column names (case sensitive). Enter 1-2 inputs, separate with spaces. Inputs correspond to (x,y) respectively.
# >  who's_featured comments
# 0.	quit
# 1.	scatterplot
# 2.	timeline
# 3.	histogram
# 4.	boxplot
# 5.	barplot
# >  0
# Quitting plotter...

# %% [markdown]
# Here are just a couple examples of weird-looking visualizations that are still generated, despite being unideal.

# %%
crochet.main()
# Out:
#     Welcome to the plotter!
#     Choose a number from this menu:
#
# 0.	quit
# 1.	scatterplot
# 2.	timeline
# 3.	histogram
# 4.	boxplot
# 5.	barplot
# >  3
# Choose some column names (case sensitive). Enter 1-2 inputs, separate with spaces. Inputs correspond to (x,y) respectively.
# >  season comments
# 0.	quit
# 1.	scatterplot
# 2.	timeline
# 3.	histogram
# 4.	boxplot
# 5.	barplot
# >  4
# Choose some column names (case sensitive). Enter 1-2 inputs, separate with spaces. Inputs correspond to (x,y) respectively.
# >  likes shares
# 0.	quit
# 1.	scatterplot
# 2.	timeline
# 3.	histogram
# 4.	boxplot
# 5.	barplot
# >  0
# Quitting plotter...
